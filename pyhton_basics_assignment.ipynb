# %% [markdown]
# ASSIGNMENT: PYTHON BASICS
#
# 1.What is Python, and why is it popular?
#  - Python is an interpreted , object-oriented , high level programming language . It is known for its simplocity and readability and it is developed by Guido Van Rossum in 1991.Pyhton is popular because it is a combination of simplicity , versatility, strong communication support . It also has libraries which ehnace the productivity ,simpllify programming tasks and extend the language capabilities .
#
# 2 What is an interpreter in Python?
#  - A Python interpreter is a computer program that executes code directly and  translates code into machine code.It provide features like interactive execution, error handling and cross platform compatibility.
#
# 3.What are pre-defined keywords in Python?
#  - Pre-defined keywords in python are the reserved words that have special meaning in the language . These keywords cannot be used as identifiers because they are part of the syntax of the language.
#  examples of keywords are : False , None, True, break, continue etc.
#
# 4.Can keywords be used as variable names?
#  - No, the keyword cannot be used as variable name because keyword define the languages syntax and structure.
#
# 5.What is mutability in Python?
#  - Mutability refers to the ability to change an object's value or state after it has been created.for example, lists and dictionaries.
#
# 6.Why are lists mutable, but tuples are immutable?
#  - list are mutable because it is designed to allow easy modifications of their elements whereas the tuples in python are immutable because once it is created the elements of tuples can't be modified further and hence it cannot be changed .
#
# 7.What is the difference between “==” and “is” operators in Python?
#  - In Python, "=="and "is" operators are both used for comparison but they serve different purposes. The "==" operator checks for equality of values which means it evaluates whether the values of two objects are the same. On the other hand, "is" operator checks for identity, meaning it determines whether two variables point to the same object in memory.
#
# 8.What are logical operators in Python?
#  -  In Python, Logical operators carry out logical operations and return Boolean values based on the result.Logical operators are used in programming to create test expressions that control program flow.
#
# 9.What is type casting in Python?
#  - Type casting in Python is the process of converting a variable's data type to another data type. It's also known as type conversion.
#
# 10.What is the difference between implicit and explicit type casting?
#  -  Implicit type casting occurs when the compiler automatically converts a smaller type to a larger type when there is no loss of data while the explicit type casting occurs when the programmer manually changes the data type of a value and there is a possibility of loss of data .
#
# 11.What is the purpose of conditional statements in Python?
#  - The purpose of conditional statements in Python is to control the flow of a program by making decisions based on certain conditions.It makes code more easier and efficient to read .
#
# 12.How does the elif statement work?
#   - In Python, elif is short form of  "else-if" and is used when the first if statement isn't true, but we want to check for another condition.
#
# 13.What is the difference between for and while loops?
#  - In Python programming language for loop is used when the number of iterations is already known and While loop is used when the number of iterations is unknown.
#
# 14.Describe a scenario where a while loop is more suitable than a for loop.
#  -  we use a while loop if we do not know how many times a loop will need to run because while loops are ideal when the number of iterations is not predetermined. To do number calculations, both while and for loops can be used, but typically a for loop is preferred if you know the exact number of iteration.

# %%
# Practical Questions
#1. Write a Python program to print "Hello, World!
     '''answer'''
print("Hello, World ")

#2. Write a Python program that displays your name and age.
        '''answer'''
print("My name is Kaenat Afzal and my age is 20")

#3. Write code to print all the pre-defined keywords in Python using the keyword library.
     '''answer'''
import keyword

# printing all keywords at once using "kwlist()"
print("The list of keywords is : ")
print(keyword.kwlist)
# Out:
# Hello, World
# My name is Kaenat Afzal and my age is 20
#
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
#4. Write a program that checks if a given word is a Python keyword.

    '''answer'''

import keyword
def is_keyword(word):
  if keyword.iskeyword(word):
    return f"'{word}'is a Python keyword."
  else:
    return f"'{word}' is not a python keyword."

#5. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.
#creating  a list

  '''answer'''

my_list=[1,2,"apple","cat",98.7]
print("original list:",my_list)

#modifying list
my_list[2]="dog"
print("modified list",my_list)

#creating a tuple
my_tuple=(1,2,"batman","spiderman",45.8)
print("original tuple",my_tuple)

#modifying tuple
my_tuple[1]="ironman"
print("modified tuple",my_tuple)  #it will throw an error as tuple is immutable


#6. Write a function to demonstrate the behavior of mutable and immutable arguments.

    '''answer'''

def modify_args(my_list, my_number):
    # Modify mutable argument (list)
    my_list.append(4)

    # Attempt to modify immutable argument (number)
    my_number += 1

    return my_list, my_number

# Demonstration
original_list = [1, 2, 3]
original_number = 10

print("Before function call:")
print("List:", original_list)
print("Number:", original_number)

# Call the function
modified_list, modified_number = modify_args(original_list, original_number)

print("\nAfter function call:")
print("List:", original_list)  # List is modified
print("Number:", original_number)  # Number remains unchanged


#7. Write a function to demonstrate the behavior of mutable and immutable arguments.

    '''answer'''

def modify_args(lst, num):
    # Modify mutable list
    lst.append(4)

    # Attempt to modify immutable number
    num += 1

    return lst, num

# Demonstration
data = [1, 2, 3]
value = 10

print("Before:", data, value)
modified_list, modified_num = modify_args(data, value)

print("After:", data, value)

#8. Write a program to demonstrate the use of logical operators.

    '''answer'''

a,b,c=True ,True ,False
if(a  and b):
  print("it is the condition where both a and b are true.")
if(a or c):
  print("it is the condition where a is true and c is false. ")
if(not c):
  print("here c is false .")

#9. Write a Python program to convert user input from string to integer, float, and boolean types.

       '''answer'''

# User input
a_str = input("Enter a number: ")
bool_str = input("Enter true or false: ")

# Convert to integer
number_int = int(a_str)
print("Integer:", number_int)

# Convert to float
number_float = float(a_str)
print("Float:", number_float)

# Convert to boolean
is_true = bool_str.lower() in ['true', '1', 'yes']
print("Boolean:", is_true)

#10. Write code to demonstrate type casting with list elements.

    '''answer'''

# Original list
numbers = [1, 2, 3, 4, 5]

# Type casting
str_numbers = [str(x) for x in numbers]
float_numbers = [float(x) for x in numbers]
bool_numbers = [bool(x) for x in numbers]

# Print results
print("Original List:", numbers)
print("String List:", str_numbers)
print("Float List:", float_numbers)
print("Boolean List:", bool_numbers)

#11. Write a program that checks if  a number if positive , negative and 0.

         '''answer'''

num=int(input("enter a number:"))
if (num>0):
  print("number is positive")
elif(num<0):
  print("number is negative")
else:
  print("number is 0")

#12. Write a for loop to print numbers from 1 to 100.

     '''answer'''

for i in range(1,101):
  print(i)

#13. Write a Python program to find the sum of all even numbers between 1 and 50.

     '''answer'''

num=1
sum=0
while (num<=50):
  sum=sum+num
  print("step wise sum:",sum)
  num=num+1
print("final sum:",sum)

#14. Write a program to reverse a string using a while loop.

        '''answer'''

a="hello world"
i=len(a)-1
while i>=0:
  print(a[i],end='')
  i=i-1

#15. Write a Python program to calculate the factorial of a number provided by the user using a while loop.

 '''answer'''

num=int(input("enter any number:"))
factorial=1
while (num>=1):
  factorial *=num
  num-=1
print("factorial :",factorial)
